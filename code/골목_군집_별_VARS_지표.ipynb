# %% [markdown]
# <a href="https://colab.research.google.com/github/dahlia52/Commercial-District-Analysis/blob/main/code/%EA%B3%A8%EB%AA%A9_%EA%B5%B0%EC%A7%91_%EB%B3%84_VARS_%EC%A7%80%ED%91%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

import seaborn as sns
import numpy as np

# %%
score = pd.read_csv('/content/drive/MyDrive/광진구팟/Data/상권분석/score.csv')
score.head(3)
# Out:
#    상권_코드_명 상권_구분_코드_명 행정동명  상권_변화_지표  임대료_불안정성         전체 매출  업종_종류수  \
# 0    세종대학교       골목상권  군자동         4  2.061089  4.287648e+09       7
# 1   장안초등학교       골목상권  군자동         1  2.061089  2.312527e+09       5
# 2  능동우편취급국       골목상권  군자동         1  2.061089  1.829857e+10      29
#
#    도보 5분 이내 보행자우선도로 개수  가까운 버스정류장까지 거리  650m_반경내_버스_노선수  가까운 지하철역까지 거리  \
# 0                    3        0.913078               25       0.191643
# 1                    5        1.441063               23       0.178571
# 2                    4        0.496948               19       0.137336
#
#    650m_반경내_역수
# 0            2
# 1            4
# 2            0

# %%
nearby = pd.read_csv('/content/drive/MyDrive/광진구팟/Data/골목상권 클러스터.csv')
nearby
# Out:
#        상권_코드_명  label
# 0     건대입구역 1번      1
# 1     건대입구역 6번      0
# 2      광나루역 1번      1
# 3        광진경찰서      1
# 4         광진구청      1
# 5       광진정말공원      0
# 6      광진정보도서관      0
# 7       광진초등학교      1
# 8       구남초등학교      1
# 9     구의1동주민센터      0
# 10      구의역 4번      0
# 11    국립정신건강센터      1
# 12      군자역 4번      1
# 13      군자역 5번      1
# 14     능동우편취급국      0
# 15      대원고등학교      1
# 16       동대부여고      1
# 17      동의초등학교      1
# 18   뚝섬유원지역 1번      1
# 19      성동초등학교      1
# 20      성자초등학교      1
# 21       세종대학교      1
# 22      신자초등학교      1
# 23     아차산역 1번      0
# 24     아차산역 5번      1
# 25  어린이대공원역 3번      1
# 26  어린이대공원역 4번      1
# 27      용마초등학교      0
# 28    자양4동주민센터      0
# 29      자양동우체국      1
# 30     자양한강도서관      0
# 31    장로회신학대학교      1
# 32      장안초등학교      1
# 33   중곡1동 마을마당      1
# 34    중곡1동주민센터      1
# 35    중곡3동주민센터      0
# 36    중곡4동주민센터      1
# 37     중곡어린이공원      1
# 38      중곡역 3번      0
# 39      푸른동산공원      1
# ...

# %%
nearby_score = pd.merge(score, nearby, on = '상권_코드_명', how = 'inner')
nearby_score
# Out:
#        상권_코드_명 상권_구분_코드_명  행정동명  상권_변화_지표  임대료_불안정성         전체 매출  업종_종류수  \
# 0        세종대학교       골목상권   군자동         4  2.061089  4.287648e+09       7
# 1       장안초등학교       골목상권   군자동         1  2.061089  2.312527e+09       5
# 2      능동우편취급국       골목상권   군자동         1  2.061089  1.829857e+10      29
# 3    중곡1동 마을마당       골목상권  중곡1동         2  2.198997  1.150311e+10      14
# 4     중곡1동주민센터       골목상권  중곡1동         1  2.198997  1.088088e+09       6
# 5      중곡어린이공원       골목상권  중곡1동         4  2.198997  6.151680e+09      13
# 6        광진경찰서       골목상권  구의1동         4  2.964346  2.539555e+09       9
# 7     구의1동주민센터       골목상권  구의1동         1  2.964346  3.362525e+10      31
# 8        동대부여고       골목상권  구의1동         1  2.964346  1.291220e+10      25
# 9       신자초등학교       골목상권  자양3동         3  3.045725  1.407709e+10      28
# 10   뚝섬유원지역 1번       골목상권  자양3동         3  3.045725  5.258867e+09      15
# 11     자양한강도서관       골목상권  자양2동         1  2.019069  2.800362e+10      31
# ...

# %%
nearby_score0 = nearby_score[nearby_score.label == 0]
nearby_score0
# Out:
#      상권_코드_명 상권_구분_코드_명  행정동명  상권_변화_지표  임대료_불안정성         전체 매출  업종_종류수  \
# 2    능동우편취급국       골목상권   군자동         1  2.061089  1.829857e+10      29
# 7   구의1동주민센터       골목상권  구의1동         1  2.964346  3.362525e+10      31
# 11   자양한강도서관       골목상권  자양2동         1  2.019069  2.800362e+10      31
# 15    광진정말공원       골목상권  자양1동         1  5.360563  2.469154e+10      32
# 17    구의역 4번       골목상권  자양1동         1  5.360563  4.461443e+10      43
# 21     화양사거리       골목상권   화양동         1  2.713627  2.838047e+10      24
# 22   광진정보도서관       골목상권   광장동         1  2.452189  3.247321e+10      21
# 25  자양4동주민센터       골목상권  자양4동         2  2.083333  2.788708e+10      34
# 26  건대입구역 6번       골목상권  자양4동         1  2.083333  6.656748e+10      37
# 32   아차산역 1번       골목상권  중곡4동         1  2.193700  3.019082e+10      34
# 39    용마초등학교       골목상권  중곡2동         4  2.407019  3.072600e+10      37
# 40    중곡역 3번       골목상권  중곡3동         1  3.651484  2.219462e+10      32
# ...

# %%
nearby_score0['도보 5분 이내 보행자우선도로 개수'].mean()
# Out:
# 1.7692307692307692

# %%
nearby_score0['가까운 버스정류장까지 거리'].mean()
# Out:
# 1.1529737467358565

# %%
nearby_score0['650m_반경내_버스_노선수'].mean()
# Out:
# 15.76923076923077

# %%
nearby_score0['가까운 지하철역까지 거리'].mean()
# Out:
# 0.14875473102361683

# %%
nearby_score1 = nearby_score[nearby_score.label == 1]
nearby_score1
# Out:
#        상권_코드_명 상권_구분_코드_명  행정동명  상권_변화_지표  임대료_불안정성         전체 매출  업종_종류수  \
# 0        세종대학교       골목상권   군자동         4  2.061089  4.287648e+09       7
# 1       장안초등학교       골목상권   군자동         1  2.061089  2.312527e+09       5
# 3    중곡1동 마을마당       골목상권  중곡1동         2  2.198997  1.150311e+10      14
# 4     중곡1동주민센터       골목상권  중곡1동         1  2.198997  1.088088e+09       6
# 5      중곡어린이공원       골목상권  중곡1동         4  2.198997  6.151680e+09      13
# 6        광진경찰서       골목상권  구의1동         4  2.964346  2.539555e+09       9
# 8        동대부여고       골목상권  구의1동         1  2.964346  1.291220e+10      25
# 9       신자초등학교       골목상권  자양3동         3  3.045725  1.407709e+10      28
# 10   뚝섬유원지역 1번       골목상권  자양3동         3  3.045725  5.258867e+09      15
# 12      성동초등학교       골목상권  자양2동         4  2.019069  1.502494e+10      23
# 13      자양동우체국       골목상권  자양2동         1  2.019069  1.031613e+10      29
# 14      성자초등학교       골목상권  자양2동         2  2.019069  1.953902e+10      33
# ...

# %%
nearby_score1['도보 5분 이내 보행자우선도로 개수'].mean()
# Out:
# 1.4137931034482758

# %%
nearby_score1['가까운 버스정류장까지 거리'].mean()
# Out:
# 1.0015292090532617

# %%
nearby_score1['650m_반경내_버스_노선수'].mean()
# Out:
# 18.655172413793103

# %%
nearby_score1['가까운 지하철역까지 거리'].mean()
# Out:
# 0.28348011470709644
